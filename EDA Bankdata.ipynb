# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bank_df=pd.read_csv(r"C:\Users\samud\OneDrive\Documents\Naresh it\datasets\bankdata.csv",sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
cat_columns=bank_df.select_dtypes(include='object').columns
num_columns=bank_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
bank_df.loc[:,'balance']
bank_df.iloc[:,[8]]
bank_df[['balance']]
# Out:
#       balance
# 0        1787
# 1        4789
# 2        1350
# 3        1476
# 4           0
# ...       ...
# 4516     -333
# 4517    -3313
# 4518      295
# 4519     1137
# 4520     1136
#
# [4521 rows x 1 columns]

# %%
len(bank_df['balance'])
# Out:
# 4521

# %%
bank_df.iloc[3:7,2:5]
# Out:
#    marital  education default
# 3  married   tertiary      no
# 4  married  secondary      no
# 5   single   tertiary      no
# 6  married   tertiary      no

# %%
count=len(bank_df['balance'])
min_wage=min(bank_df['balance'])
max_wage=max(bank_df['balance'])
print("the number of wage sample are:",count)
print("the minimum wage is:",min_wage)
print("the maxmim wage is:",max_wage)
# Out:
# the number of wage sample are: 4521
# the minimum wage is: -3313
# the maxmim wage is: 71188

# %% [markdown]
# **Mean**

# %%
bank_df['balance'].mean()
# Out:
# 1422.6578190665782

# %% [markdown]
# **Meadian**

# %%
bank_df['balance'].median()
# Out:
# 444.0

# %%
mean_wage=round(bank_df['balance'].mean(),2)
median_wage=round(bank_df['balance'].median(),2)
print("the average wage is:",mean_wage)
print("the median wage is:",median_wage)
# Out:
# the average wage is: 1422.66
# the median wage is: 444.0

# %% [markdown]
# **numpy**

# %%
np.mean(bank_df['balance'])
# Out:
# 1422.6578190665782

# %%
np.median(bank_df['balance'])
# Out:
# 444.0

# %% [markdown]
# **Standard deviation**

# %%
std_wage=round(bank_df['balance'].std(),2)
std_wage
# Out:
# 3009.64

# %%
count_wage=len(bank_df['balance'])
min_wage=min(bank_df['balance'])
max_wage=max(bank_df['balance'])
print("the number of wage sample are:",count)
mean_wage=round(bank_df['balance'].mean(),2)
median_wage=round(bank_df['balance'].median(),2)
std_wage=round(bank_df['balance'].std(),2)
# Out:
# the number of wage sample are: 4521

# %%
values=[count_wage,min_wage,max_wage,
 mean_wage,median_wage,std_wage]
index=['count','min','max','mean','median','std']
cols=['balance']
pd.DataFrame(values,index=index,columns=cols)
# Out:
#          balance
# count    4521.00
# min     -3313.00
# max     71188.00
# mean     1422.66
# median    444.00
# std      3009.64

# %%
bank_df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
bank_df['balance'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4516    False
# 4517    False
# 4518    False
# 4519    False
# 4520    False
# Name: balance, Length: 4521, dtype: bool

# %% [markdown]
# **percentile**

# %% [markdown]
# - In numpy we have percentile
#
# - the method is no.percentile()
#
#     - it takes the  two arguments
#     - a: array mean data
#     - q value which percentile data we want, that value we need to provide
#     - if we want 25p value then q=25
#
# **quantile**
#
# - in numpy we have quatile method
#
# - the method is np.quantile()
#
# - it takes the two arrguments
#
#     - a : array mean data
#     - q value which percentile data we want ,that value we need to provide
#     - if we want 25p value then q=0.25
#     - if we want 50p value then q=0.50

# %%
np.percentile(bank_df['balance'],25)
# Out:
# 69.0

# %%
np.quantile(bank_df['balance'],0.25)
# Out:
# 69.0

# %%
wage_25p=round(np.percentile(bank_df['balance'],25),2)
wage_50p=round(np.percentile(bank_df['balance'],50),2)
wage_75p=round(np.percentile(bank_df['balance'],75),2)
print("25p value is:",wage_25p)
print("50p value is:",wage_50p)
print("75p value is:",wage_75p)
# Out:
# 25p value is: 69.0
# 50p value is: 444.0
# 75p value is: 1480.0

# %%
df1=pd.DataFrame()
for i in num_columns:
    Count=len(bank_df[i])
    Min=min(bank_df[i])
    Max=max(bank_df[i])
    Mean=round(bank_df[i].mean(),2)
    Median=round(bank_df[i].median(),2)
    Std=round(bank_df[i].std(),2)
    P_25=round(np.percentile(bank_df[i],25),2)
    P_50=round(np.percentile(bank_df[i],50),2)
    P_75=round(np.percentile(bank_df[i],75),2)
    values=[Count,Min,Max,
            Mean,Median,Std,P_25,P_50,P_75]
    index=['count','min','max','mean','median','std','25p','50p','75p']
    cols=[i]

# %%
df2=pd.DataFrame(values,index=index,columns=cols)
df1=pd.concat([df1,df2],axis=1)

# %%
df1
# Out:
#         previous
# count    4521.00
# min         0.00
# max        25.00
# mean        0.54
# median      0.00
# std         1.69
# 25p         0.00
# 50p         0.00
# 75p         0.00

# %% [markdown]
# **percentiles**
# - 25p
#   - assume that 25p values=x
#   - 25p of data less than value : x
# - for ecample prevailing_wage 25p values is : 34015.47
# - 25 percentage of people having salary less then 34015.47
# - total mwmbers : 25480
# - 25percentage of 25480=6370
# - which means 6370 people has salary less then 34015.47

# %%
np.percentile(bank_df['balance'],25) # 0 to 100
# Out:
# 69.0

# %%
# step-1: read the balance
# step-2: provide the condition
# balance < percentile value
wage_data=bank_df['balance']
p_25=np.percentile(bank_df['balance'],25)
con=wage_data<p_25
bank_df[con]
# Out:
#       age            job   marital  education default  balance housing loan  \
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 9      43       services   married    primary      no      -88     yes  yes
# 18     25    blue-collar    single    primary      no     -221     yes   no
# 20     38     management  divorced    unknown      no        0     yes   no
# 21     42     management  divorced   tertiary      no       16      no   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4497   31   entrepreneur    single   tertiary      no       38      no   no
# 4502   42       services   married  secondary      no      -91     yes  yes
# 4506   42     unemployed  divorced   tertiary      no     -166      no   no
# 4516   33       services   married  secondary      no     -333     yes   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
#
# ...

# %%
len(bank_df[con])
# Out:
# 1129

# %%
wage_data=bank_df['balance']
p_50=np.percentile(bank_df['balance'],50)
con=wage_data<p_50
bank_df[con]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4      59    blue-collar  married  secondary      no        0     yes   no
# 6      36  self-employed  married   tertiary      no      307     yes   no
# 7      39     technician  married  secondary      no      147     yes   no
# 8      41   entrepreneur  married   tertiary      no      221     yes   no
# 9      43       services  married    primary      no      -88     yes  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4507   33       services  married  secondary      no      288     yes   no
# 4513   49    blue-collar  married  secondary      no      322      no   no
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
#
# ...

# %%
np.percentile(bank_df['balance'],50)
# Out:
# 444.0

# %%
len(bank_df[con])
# Out:
# 2259

# %%
mu=bank_df['balance'].mean()
sigma=bank_df['balance'].std()
lb=mu-1*sigma
ub=mu+1*sigma
con1=bank_df['balance']<ub
con2=bank_df['balance']>lb
con3=con1&con2
bank_df[con3]
# Out:
#       age           job  marital  education default  balance housing loan  \
# 0      30    unemployed  married    primary      no     1787      no   no
# 2      35    management   single   tertiary      no     1350     yes   no
# 3      30    management  married   tertiary      no     1476     yes  yes
# 4      59   blue-collar  married  secondary      no        0     yes   no
# 5      35    management   single   tertiary      no      747      no   no
# ...   ...           ...      ...        ...     ...      ...     ...  ...
# 4515   32      services   single  secondary      no      473     yes   no
# 4516   33      services  married  secondary      no     -333     yes   no
# 4518   57    technician  married  secondary      no      295      no   no
# 4519   28   blue-collar  married  secondary      no     1137      no   no
# 4520   44  entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
mu=bank_df['balance'].mean()
sigma=bank_df['balance'].std()
lb=mu-1*sigma
ub=mu+1*sigma
con1=bank_df['balance']<ub
con2=bank_df['balance']>lb
con3=con1&con2
print(len(bank_df[con3]))
print(68*len(bank_df)/100)
# Out:
# 4143
# 3074.28

# %%
# import the packages
# read the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
path=r"C:\Users\samud\OneDrive\Documents\Naresh it\datasets\bankdata.csv"
bank_df=pd.read_csv(path,sep=';')
cat_columns=bank_df.select_dtypes(include='object').columns
num_columns=bank_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
bank_df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
# step-1: Read the prevaialingwage
# step-2: plt.hist()
wage_data=(bank_df['balance'])
plt.hist(wage_data,bins=20)
# Out:
# (array([2.172e+03, 1.939e+03, 2.590e+02, 8.100e+01, 3.200e+01, 1.500e+01,
#         1.100e+01, 6.000e+00, 4.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([-3313.  ,   412.05,  4137.1 ,  7862.15, 11587.2 , 15312.25,
#         19037.3 , 22762.35, 26487.4 , 30212.45, 33937.5 , 37662.55,
#         41387.6 , 45112.65, 48837.7 , 52562.75, 56287.8 , 60012.85,
#         63737.9 , 67462.95, 71188.  ]),
#  <BarContainer object of 20 artists>)

# %%
wage_data=bank_df['balance']
count,bins,x=plt.hist(wage_data,bins=10)
print(len(count))
print(len(bins))
print(x)
# Out:
# 10
# 11
# <BarContainer object of 10 artists>

# %%
lb=1.939e+03
ub=2.172e+03
con1=bank_df['balance']<ub
con2=bank_df['balance']>lb
con3=con1&con2
print(len(bank_df[con3]))
# Out:
# 73

# %%
lb=-3313
ub= 4137.1
con1=bank_df['balance']<ub
con2=bank_df['balance']>lb
con3=con1&con2
print(len(bank_df[con3]))
# Out:
# 4110

# %%
count
# Out:
# array([4.111e+03, 3.400e+02, 4.700e+01, 1.700e+01, 4.000e+00, 0.000e+00,
#        1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00])

# %%
bins
# Out:
# array([-3313. ,  4137.1, 11587.2, 19037.3, 26487.4, 33937.5, 41387.6,
#        48837.7, 56287.8, 63737.9, 71188. ])
